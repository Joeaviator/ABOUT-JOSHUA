# %% [markdown]
# <a href="https://colab.research.google.com/github/Joeaviator/ABOUT-JOSHUA/blob/main/Correlation_B_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/content/gapminder(2007).csv')
df.head(30)
# Out:
#     Unnamed: 0                   country  year  population continent  \
# 0           11               Afghanistan  2007    31889923      Asia
# 1           23                   Albania  2007     3600523    Europe
# 2           35                   Algeria  2007    33333216    Africa
# 3           47                    Angola  2007    12420476    Africa
# 4           59                 Argentina  2007    40301927  Americas
# 5           71                 Australia  2007    20434176   Oceania
# 6           83                   Austria  2007     8199783    Europe
# 7           95                   Bahrain  2007      708573      Asia
# 8          107                Bangladesh  2007   150448339      Asia
# 9          119                   Belgium  2007    10392226    Europe
# 10         131                     Benin  2007     8078314    Africa
# 11         143                   Bolivia  2007     9119152  Americas
# 12         155    Bosnia and Herzegovina  2007     4552198    Europe
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  142 non-null    int64
#  1   country     142 non-null    object
#  2   year        142 non-null    int64
#  3   population  142 non-null    int64
#  4   continent   142 non-null    object
#  5   life_exp    142 non-null    float64
#  6   gdp_cap     142 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# country       0
# year          0
# population    0
# continent     0
# life_exp      0
# gdp_cap       0
# dtype: int64

# %% [markdown]
# #EDA Findings
# * 142 entries
# * There are 7 columns
# * dtypes: float64(2), int64(3), object(2)
# * No null values:
#
# * Unnamed: 0	0
# * country	0
# * year	0
# * population	0
# * continent	0
# * life_exp	0
# * gdp_cap	0

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'year', 'population', 'continent', 'life_exp',
#        'gdp_cap'],
#       dtype='object')

# %%
df=df.drop(columns = ["Unnamed: 0" , "continent", "country"],axis=1)

# %%
sns.scatterplot(x='life_exp', y='gdp_cap', data=df)
# Out:
# <Axes: xlabel='life_exp', ylabel='gdp_cap'>

# %%
sns.scatterplot(x='population', y='year', data=df)
# Out:
# <Axes: xlabel='population', ylabel='year'>

# %%
df.head()
# Out:
#    year  population  life_exp       gdp_cap
# 0  2007    31889923    43.828    974.580338
# 1  2007     3600523    76.423   5937.029526
# 2  2007    33333216    72.301   6223.367465
# 3  2007    12420476    42.731   4797.231267
# 4  2007    40301927    75.320  12779.379640

# %%
sns.heatmap(df.corr() ,annot=True)
# Out:
# <Axes: >
